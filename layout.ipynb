# %% [markdown]
# # Projeto 1 - Ciência dos Dados

# %% [markdown]
# Nome: Luís Filipe Martins Loureiro

# %% [markdown]
# ## Perguntas a serem  respondidas pelo estudo

# %% [markdown]
# - Um pensamento sustentado por alguns grupos de economistas é baseado na defesa que se deve priorizar a manufatura de bens de alto valor agregado em detrimento do agrobusiness. Tal análise tem base empírica? Nos países mais ricos, pertencentes à OCDE, a agricultura não é parte relevante em seu PIB? E no caso dos países em desenvolvimento, pertencentes ao grupo BRICS? Como esses dois grupos comparam-se a media mundial nesse quesito?
#
#
# - Nos países mais ricos (membros da OCDE) há uma queda vertiginosa quando comparado a exportação de alta tecnologia e exportação de produtos agrículas? Tal padrão se mantém entre os membros dos BRICS e o restante do mundo?
#
#
# - A importância da agricultura no PIB tem relação com a riqueza de um país ou com a quantidade de área plantável disponível?

# %% [markdown]
# ## Introdução

# %% [markdown]
# Em seu artigo, Economia global e a nova Divisão Internacional do Trabalho [i], Márcio Pochmann disserta sobre como se dá a produção de bens e serviços ao redor no mundo nas últimas décadas. No texto, ele chega na conclusão que a distribuição de riqueza desigual deriva da diferença dos bens que são consumidos e vendidos dentro de cada país, sendo os mais desenvolvidos focados em bens de alta tecnologia, enquanto os países em desenvolvimento focados em commodities e agrobusiness. Dessa maneira, Pochmann faz defesa de uma intervanção estatal em prol de uma maior produção de bens de consumo de alto valor agregado em detrimento da agricultura.
#
# Seguindo a linha de racicínio heterodoxa, adotada por Márcio Pochmann, o artigo escrito por Pamela Coke-Hamilton, We must help developing countries escape commodity dependence [ii], defende que o agrobusiness e os commodities são importantes, mas que a sua dependência é perigosa e é uma característica de países pobres ou em desenvolvimento.
#
#
# Assim, esse estudo tem como objetivo colocar as teses formuladas por Pochmann [i] em uma prova empírica; há de fato uma correlação entre países ricos e uma baixa importância da agricultura em seu PIB ou na verdade fatores como território apresentam uma maior correlação. Além disso, os países mais ricos (pertencentes à OCDE) seriam mesmo os maiores players no mercado de produtos de alta tecnologia, ou há também países em desenvolvimento (pertencente aos BRICS) nesse segmento de mercado.
#
# Ademais, será posto a prova a posição de Coke-Hamilton [ii], os países mais pobres dependem mais da agricultura que os desenvolvidos? Ou a importância de agricultura na economia do Estado está atrelada a quantidade de terras disponíveis para plantio?
#
# A partir desses indicadores quantitativos, será feito uma análise qualitativa baseando-se na qualidade da educação, observando se os países que mais investem em seus alunos são também aqueles com maior investimento em alta tecnologia. Por fim, será colocado em perspectiva a qualidade da democracia em relação à educação.

# %% [markdown]
# ## Referência dos artigos mencionados na introdução

# %% [markdown]
# i. POCHMANN, Marcio. Economia global e a nova Divisão Internacional do Trabalho: subtítulo do artigo. UNICAMP: Centro de Estudos Sindicais e de Economia do Trabalho (CESIT), Campinas, v. 1, n. 1, p. 1-19, set./2000. Disponível em: http://decon.edu.uy/network/panama/POCHMANN.PDF. Acesso em: 20 ago. 2019.
#
#
# ii. COKE-HAMILTON, Pamela. We must help developing countries escape commodity dependence: here are grave economic, social and environmental consequences for the developing world. World Economic Forum, UNCTAD, v. 1, n. 1, p. 1-1, mai./2016. Disponível em: <https://www.weforum.org/agenda/2019/05/why-commodity-dependence-is-bad-news-for-all-of-us/>. Acesso em: 20 ago. 2019.

# %% [markdown]
# ## Hipóteses

# %% [markdown]
# É de se esperar que os países mais ricos de fato investem mais em produtos de alta tecnologia devido a sua expertise e investimento necessário. Entretanto, a hipótese a ser colocada a prova é:  países em que a agricultura tem grande importância na sua economia também podem ser grandes investidores em alta tecnologia. Dessa maneira, não sendo questões opostas como defendido por Márcio Pochmann.
#
# Além disso, a questão da agricultura está muito mais atrelada a quantidade de terras disponíveis do que a riqueza do país. Os Estados não precisam abrir mão de seu potencial produtivo para investir apenas em tecnologia.

# %% [markdown]
# ## Importe as bibliotecas necessárias

# %%
#Importando as bibliotecas necessárias
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.patches as mpatches

# %% [markdown]
# ## Referências em ABNT utilizadas

# %% [markdown]
# I. GAPMINDER. GDP per capity, 2005 ppp, WB data. Disponível em: https://docs.google.com/spreadsheets/d/1TuLhfdvskeJYaQziz7M0W6vMfh4zyGFQZoeoBrAotyA/pub. Acesso em: 20 ago. 2019.
#
#
# II. GAPMINDER. Agriculture, value added (% of GDP). Disponível em: https://docs.google.com/spreadsheets/d/16JAXDjaKcyaEfd6sO_pRC892NG8VAk6moyw3Gl50-Ys/pub. Acesso em: 20 ago. 2019.
#
#
# III.GAPMINDER. High-technology exports (% of manufactured exports). Disponível em: https://docs.google.com/spreadsheets/d/1fKPK2n060wZHu_tLXprcEs2l8LG1gS69Wqc6Zv9W1W4/pub. Acesso em: 20 ago. 2019.
#
#
# IV. GAPMINDER. Total Population. Disponível em: https://docs.google.com/spreadsheet/pub?key=0AkBd6lyS3EmpdGVSdkZnZWhfMDYybzd6U2p3NkxsZ3c. Acesso em: 20 ago. 2019.
#
#
# V. GAPMINDER. % of agricutural land. Disponível em: https://docs.google.com/spreadsheet/pub?key=0ArfEDsV3bBwCdGQ2YlhDSWVIdXdpMmhLY2ZZRHdNNnc. Acesso em: 20 ago. 2019.

# %%
pib=pd.read_excel('gdp_per_year.xlsx') #PIB em dolares com inflacao ajustada 
agri_porc = pd.read_excel('AgriculturepforGDP.xlsx') #Porcentagem do PIB que corresponde à agricultura
hightech_export = pd.read_excel('high_tech_export.xlsx') #Porcentagem da comercialização de bens de manofatura que corresponde a bens hightech
populacao=pd.read_excel('population_total.xlsx') #População total de cada país
land_agri=pd.read_excel("agricultural_land_percent_of_land_area.xlsx") #Porcentagem correspondente a área disponível para plantio em cada país

# %% [markdown]
# ## Arrumando os dados

# %% [markdown]
# Para todos os DataFrames é mais interessante para a sua manipulação transformar os países em index

# %%
pib_idx = pib.set_index('Country')
agri_idx = agri_porc.set_index("Country")
hightech_idx = hightech_export.set_index('Country')
education_idx = education.set_index("Country")
democracia_idx = democracia.set_index("Country")
populacao_idx= populacao.set_index("Country")
land_agri_idx = land_agri.set_index("country")

# %% [markdown]
# Como a análise se dará levando em consideração dois grupos, OCDE e BRICS, e tal rotulação não está presente nos DataFrames é necessário criar

# %%
#Criando a coluna BRICS 
pib_idx["BRICS"] = 0
agri_idx["BRICS"] = 0
hightech_idx["BRICS"] = 0

#Criando o grupo que irá se repetir
brics =["Brazil", "China","India","South Africa", "Russia"]
#Mudando a coluna dos membros dos BRICS
pib_idx.loc[brics, "BRICS" ] = 1
agri_idx.loc[brics, "BRICS" ] = 1
hightech_idx.loc[brics, "BRICS" ] = 1



#democracia_idx.loc[democracia_idx["BRICS"] == 1]  teste

#Criando a coluna OCDE

pib_idx["OCDE"]=0
agri_idx["OCDE"] = 0
hightech_idx["OCDE"] = 0

#Criando o grupo que irá se repetir
ocde = [ "United States","United Kingdom", "Turkey", "Switzerland", "Sweden", "Spain", "Slovenia", "Slovak Republic", "Portugal", "Poland", "Norway", "New Zealand","Netherlands", "Mexico", "Luxembourg", "Lithuania", "Latvia", "Japan", "Italy", "Israel", "Ireland", "Iceland", "Hungary", "Greece", "Germany", "France", "Finland", "Estonia", "Denmark", "Czech Rep.", "Chile", "Canada", "Belgium", "Austria", "Australia"]
#Mudando a coluna dos membros da OCDE
pib_idx.loc[ocde,"OCDE"]=1
agri_idx.loc[brics, "OCDE" ] = 1
hightech_idx.loc[brics, "OCDE" ] = 1

# %% [markdown]
# ## Análise de dados

# %% [markdown]
# ## Gráfico 1

# %% [markdown]
# Gráfico 1: Média do PIB per captade cada país por ano
#
#
# A alocação do gráfico abaixo como o primeiro a ser apresetado tem o propósito de deixar claro a preponderância dos países membros da OCDE quando se trata de riqueza. Desde o primeiro ano tais países mostraram-se com um PIB per capta muito superior aos demais e mentiveram uma taxa de crescimento considerável até 2005, quando percebe-se uma desaceleração, mesmo momento em que os membros dos BRICS e o mundo intensificam o seu desenvolvimento.
#
# Além disso, o gráfico em questão tem uma importância fundamental nesse estudo, por apresentar visualmente as diferenças entre os países, uma vez que pretende-se analisar se há correlação entre tal distinção e a exportação de alta tecnologia e a importância da agricultura na economia do país.

# %%
#Como foi a variação do PIB de 1987 até 2011 (ano mais recente do DataFrame)

#Criando variação de tempo desejada
anos = np.arange(1987, 2011, 1)

#Criando variável que contém a média dos PIBS a cada ano
pib_ocde = pib_idx.loc[pib_idx.OCDE ==1].loc[:, anos]

pib_brics =pib_idx.loc[pib_idx.BRICS==1].loc[:,anos]

pib_mundi=pib_idx.loc[:,anos]

#Plotando o gráfico
plt.subplot(111)
plt.plot(pib_ocde.mean(), label="OCDE")
plt.plot(pib_brics.mean(),label="BRICS")
plt.plot(pib_mundi.mean(), label="Mundo")
plt.legend()

plt.ylabel("PIB per capta em milhôes de dólares")
plt.xlabel("Ano")
plt.title("Média do PIB per capta por ano")
plt.show()

# %% [markdown]
# ## Gráfico 2

# %% [markdown]
# Gráfico 2: Comparação da exportação de alta tecnologia e importância da agricultura nos últimos 30 anos
#
#
# O impacto visual tem grande relevância no Gráfico 2, pois apesar de conter muita informação ele se mostra conciso e claro.
#
# Em vermelho observa-se a média das exportações de alta tecnologia entre os países da OCDE, BRICS e restante. Um primeiro ponto salta os olhos: a quantidade de dinheiro média envolvida na exportação de high-tech por parte dos BRICS é consideravelmente superior aos membros da OCDE. Ou seja, diferente do pensamento apresentado na introdução; os maiores players no mercado nesse segmento não são restritamente países ricos.
#
# Ademais, em azul expôe-se a média da porcentagem do PIB correspondente com agricultura nos BRICS, OCDE e restante dos países. Essa questão indica que de fato o grupo dos Estados mais ricos se destaca por seu valor baixo seguido dos membros dos BRICS e restante do mundo, respectivamente. Entretanto, seria imprudente afirmar que tal relação é uma causa e consequência para determinar a riqueza do país.

# %%
hightech_limpo=hightech_idx.drop(['OCDE', 'BRICS'],  axis=1) #tirando coluna BRICS e OCDE para não contaminar a média
#hightech_limpo.loc[hightech_idx.OCDE==1,:].mean().mean()
#hightech_limpo.loc[hightech_idx.BRICS==1,:].mean().mean()
#hightech_limpo.loc[:,:].mean().mean()

agri_limpo=agri_idx.drop(['OCDE', 'BRICS'],  axis=1)
#agri_limpo.loc[agri_idx.OCDE==1,:].mean().mean()
#agri_limpo.loc[:,:].mean().mean()
#agri_limpo.loc[agri_idx.BRICS==1,:].mean().mean()

# %%
from io import StringIO
s = StringIO("""     tech     agri
BRICS     43545235000.0   17.78
OCDE     21826341385.59   8.69
MUNDO     9296541598.08   21.31""")

df = pd.read_csv(s, index_col=0, delimiter=' ', skipinitialspace=True)

fig = plt.figure() # Create matplotlib figure

ax = fig.add_subplot(111) # Create matplotlib axes
ax2 = ax.twinx() # Create another axes that shares the same x-axis as ax.

width = 0.4

df.tech.plot(kind='bar', color='red', label="tecnologia", ax=ax, width=width, position=1)
df.agri.plot(kind='bar', color='blue',label="agricultura",ax=ax2, width=width, position=0)
plt.title("Comparação da exportação de alta tecnologia e importância da agricultura nos últimos 30 anos")

ax.legend()
ax.legend(loc="upper center")
ax2.legend()



ax.set_ylabel('Exportação de tecnologia em dólares')
ax2.set_ylabel('Média da porcentagem que a agricultura corresponde do PIB')
ttl = ax2.title
ttl.set_position([.5, 1.35])



plt.show()

# %% [markdown]
# ## Gráfico 3

# %% [markdown]
# Gráfico 3: Exportação de alta tecnologia entre os BRICS, OCDE e mundo
#
# O gráfico 3 é fundamental para colocar em perpectiva os dados oferecidos pelo gráfico 2. Apesar de a média dos países dos BRICS em exportação de alta tecnologia ser ligeiramente superior que a média da OCDE, a distribuição dos países dos dois blocos apresenta-se de forma bem parecida, com exceção da China (ponto amerelo superior) que apresenta valores muito a cima do restante e como membra dos BRICS alavancou a média do grupo.
#
# O gráfico 3 aponta sobre a fragilidade de se constatar fatos apenas embasado em média, o resultado empírico aponta para uma enorme semelhança entre os membros da OCDE e BRICS quando é tratado de exportação de alta tecnologia. Interessante notar como os demais países (em verde) estão acumulados em uma faixa consideravelmente inferior.

# %%
anos2 = np.arange(1989, 2011, 1)

for ano in anos2:
    for pais in hightech_idx.index:
        if pais in ocde:
            plt.scatter(ano, hightech_idx.loc[pais, ano], color="blue")
           
        if pais in brics:
            plt.scatter(ano, hightech_idx.loc[pais, ano], color="orange")
           
        if pais not in brics:
            if pais not in ocde:
                plt.scatter(ano, hightech_idx.loc[pais, ano], color="green")

                
plt.xlabel("Anos")
plt.ylabel("Dólares exportados de alta tecnologia")
plt.title("Exportação de alta tecnologia: Membro do BRICS (laranja), Membros OCDE(azul), demais(verde)", pad=20)
plt.yscale('log')
plt.show()

# %% [markdown]
# ## Gráfico 4

# %% [markdown]
# Gráfico 4: Exportação per capta de alta tecnologia
#
#
# Quando se trata de qualquer valor absoluto de um país é fundamental colocá-lo em perspectiva (valor relativo). E assim foi feito no tocante do total em dólares exportado de alta tecnologia por país. Apesar de o gráfico 3 apresentar um cenário em que os países da OCDE e BRICS comportam-se de forma semelhante, tal padrão deixa de ser verdade quando o montante é divido pela população do país.
#
# Na camada superior, pela primeira vez observa-se pontos verdes, indicando países que não pertencem a nenhuma das duas organizações. Tais pontos referem-se aos tigres asiáticos que ganham muito mais exposição quando se trata de valores relativos devido a sua baixa população. A segunda camada é marcada por uma preponderância de países pertencentes à OCDE seguida de membros dos BRICS e, no extremo inferior, os demais países do mundo.
#
# Dessa maneira, o Gráfico 4 aponta que os países dos BRICS apresentam um volume total de exportação muito alto devido ao tamanho de sua população. Ademais, diferente do que se poderia esperar as maiores exportações high-tech per capta não são de membros de nenhuma das organizações mesmo que elas englobam as economias mais ricas (como observado no Gráfico 1).

# %%
anos1 = np.arange(1989, 2011, 1)
ocde = [ "United States","United Kingdom", "Turkey", "Switzerland", "Sweden", "Spain", "Slovenia", "Slovak Republic", "Portugal", "Poland", "Norway", "New Zealand","Netherlands", "Mexico", "Luxembourg", "Lithuania", "Latvia", "Japan", "Italy", "Israel", "Ireland", "Iceland", "Hungary", "Greece", "Germany", "France", "Finland", "Estonia", "Denmark", "Czech Rep.", "Chile", "Canada", "Belgium", "Austria", "Australia"]
brics =["Brazil", "China","India","South Africa", "Russia"]

for ano in anos1:
    for pais in hightech_idx.index:
        if pais in populacao_idx.index:
            
            if pais in ocde:
                plt.scatter(ano, (hightech_idx.loc[pais, ano] / populacao_idx.loc[pais,ano]), color="blue")

            if pais in brics:
                plt.scatter(ano, (hightech_idx.loc[pais, ano] / populacao_idx.loc[pais,ano]), color="orange")
                
                    

            if pais not in ocde:
                if pais not in brics:
                    plt.scatter(ano, (hightech_idx.loc[pais, ano] / populacao_idx.loc[pais,ano]), color="green")
                    
            
            

             
plt.xlabel("Anos")
plt.ylabel("Dólares exportados de alta tecnologia")
plt.title("Exportação per capta de alta tecnologia: Membro do BRICS (laranja), Membros OCDE(azul), demais(verde)", pad=20)
plt.yscale('log')

plt.show()

# %% [markdown]
# ## Gráfico 5

# %% [markdown]
# Gráfico 5:Porcentagem correspondente a agricultura no PIB
#
# O gráfico 5 apresenta como se comporta a distribuição dos países a cada ano quanto a porcentagem correspondente a agricultura em seu PIB. Apesar do ennorme acúmulo de pontos devido a baixa variação possível se tratando de valores porcentuais, esse gráfico é importante por apresentar uma base formada majoritariamente pos países pertencentes a OCDE (pontos em azul) enquanto que o topo apresenta uma alta quantidade de pontos verdes, indicando países não pertencentes a nenhuma das duas organizações.

# %%
years=["1989", "1990", "1991", "1992", "1993", "1994", "1995", "1996", "1997", "1998", "1999", "2000","2001", "2002", "2003", "2004", "2005", "2006", "2007", "2008", "2009", "2010"]
for ano in years:
    for pais in agri_idx.index:

        if pais in ocde:
            plt.scatter(ano, agri_idx.loc[pais, ano], color="blue")

        if pais in brics:
            plt.scatter(ano, agri_idx.loc[pais, ano], color="orange")
            

        if pais not in brics:
            if pais not in ocde:
                plt.scatter(ano, agri_idx.loc[pais, ano], color="green")

                
plt.xlabel("Anos")
plt.ylabel("% correspondente a agricultura no PIB")
plt.title("Porcentagem correspondente a agricultura no PIB: Membro do BRICS (laranja), Membros OCDE(azul), demais(verde)", pad=20)
plt.show()

# %% [markdown]
# ## Gráfico 6

# %% [markdown]
# Gráfico 6: Porcentagem correspondente a agricultura no PIB
#
# O gráfico 6 tem como objetivo diminuir a quantidade de informação que estava contida no gráfico 5 para facilitar a análise. É apresentado o comportamento apenas dos membros dos BRICS e OCDE e fica claro uma preponderância de pontos azul na base- como percebido no gráfico 5- e uma distribuição heterogênea dos membros dos BRICS.
# Apesar do fato de que os dois maiores dependentes da agricultura seerem países dos BRICS, observa-se que são casos excepcionais e que a agricultura não é uma ligação comum forte em comum entre esses Estados.
#
# Destarte, o gráfico 6 evidencia que, diferente do defendido na introdução e de acordo com as hipóteses; não há uma clara relação entre os países em desenvolvimento e agricultura, não há uma tendência consolidada.

# %%
years=["1989", "1990", "1991", "1992", "1993", "1994", "1995", "1996", "1997", "1998", "1999", "2000","2001", "2002", "2003", "2004", "2005", "2006", "2007", "2008", "2009", "2010"]
for ano in years:
    for pais in agri_idx.index:

        if pais in ocde:
            plt.scatter(ano, agri_idx.loc[pais, ano], color="blue")

        if pais in brics:
            plt.scatter(ano, agri_idx.loc[pais, ano], color="orange")
            
            
plt.xlabel("Anos")
plt.ylabel("% correspondente a agricultura no PIB")
plt.title("Porcentagem correspondente a agricultura no PIB: Membro do BRICS (laranja), Membros OCDE(azul)", pad=20)
plt.show()

# %% [markdown]
# ## Gráfico 7

# %% [markdown]
# Gráfico 7:Porcetagem do terriotorio utilizável para agricultura
#
# O gráfico 7 busca colocar em perspectiva, relativizar, os dados obtidos no Gráfico 6 onde foi percebido uma leve preponderância por parte dos países pertencentes aos BRICS em relação a dependência da agricultura em suas economias. Tal distinção pode ser percebida novamente no gráfico 7 e, dessa maneira, é possível indicar que se deve a diferença da quantidade de terras produtivas e não com relação a riqueza de cada país.
#
# Sendo assim, o gráfico 7 conclui a análise desse estudo ao apontar que a agricultura não apresenta uma forte relação com o PIB per capta do país, mas com a quantidade de terra passiva de agricultura disponível.

# %%
anos = np.arange(1987, 2011, 1)
a=land_agri_idx.loc[brics,anos].mean().mean()
b=land_agri_idx.loc[ocde,anos].mean().mean()
labels = ['BRICS', 'OCDE']
sizes = [a, b]
colors = ['red', 'blue']

patches, texts = plt.pie(sizes, colors=colors, shadow=True, startangle=90)
plt.legend(patches, labels, loc="best")

plt.title("Porcetagem do terriotorio utilizável para agricultura")
plt.axis('equal')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\luisf\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ## Conclusão

# %% [markdown]
# Como ante mencionado o objetivo desse estudo era colocar empiricamente em prova a teoria defendida na academia por economistas heterodoxos ilustrados nesse caso por Márcio Pochmann e Pamela Coke-Hamilton. Diferente de seus teses, a base de dados não apontou uma forte correlação entre a riqueza dos país e a exportação de alta tecnologia. Apesar de os países com PIB per capta mais elevados de fato preponderarem nesse segmento de mercado, existem fortes players pertencentes aos BRICS. Quando colocado em relatividade os países da OCDE ganham vantagem, entretanto, países asiáticos tomam a liderança; evidenciando uma impossibilidade de afirmar que há uma causa e consequência entre a riqueza do país e a exportação de high-tech.
#
#
# De mesmo modo, os dados utilizados nesse estudo não corroboraram com as teses de Pochmann e Coke-Hamilton sobre a intensa relação entre os países em desenvolvimento e a dependência da agricultura em suas economias. De fato os países pertencentes aos BRICS apresentaram número pouco mais elevados quando comparado aos membos da OCDE, conquanto, tal discrepância parece mais intimamente ligada com a disponibilidade de terras férteis que com a riqueza do país.
#
# Por fim, as duas hipóteses ante apresentadas se mostraram verdadeiras; não há uma relação inversa entre tecnologia e agricultura se tratando da riqueza de um país e a importância da agricultura parece, de fato, liga a disponibilidade de terras platáveis.
